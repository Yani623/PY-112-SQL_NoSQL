# %% [markdown]
# <h1>CI Final SQL Project</h1>

# %% [markdown]
# <h2>You are working at a financial firm and they have taken over a smaller client. <br>
# Your job is to convert their customers and records into your format.  <br>
# There are 2 type of records corporate and customer <br>
# <br></h2>
# <br>
# <b>NOTE: </b>All financial data can be found at https://finance.yahoo.com<br>
# Download data for the following list of securities:<br>
# 'COF','DIS','SQ','INTC','MSFT','CRM','CMG','NKE','AMD','UA'<br>
#
# ** You should download the last 5 years worth of data.<br>

# %% [markdown]
# #### 1. Place your project directory variable in the code block below - 5 points
# ```
# project_dir = 'C:\\temp\final_project\\'  # <--- USE YOUR DIRECTORY
# # 5 easy points
# ```

# %%
project_dir = '/Users/yani/Desktop/PY-112-MySQL/Final Project'

# %% [markdown]
# <h4>2. Download the historical data (5 years) from finance.yahoo.com - 5 points<br>
# print a list of all csv files in your project directory</h4>

# %%
import os 
os.chdir('/Users/yani/Desktop/PY-112-MySQL/Final Project')
files = os.listdir('.')

py_files = [py_file for py_file in os.listdir('.') if py_file.endswith(".csv")]
print(py_files)
# Out:
# ['INTC.csv', 'corp_transactions.csv', 'cust_transactions.csv', 'MSFT.csv', 'corp_accounts.csv', 'CMG.csv', 'AMD.csv', 'NKE.csv', 'cust_accounts.csv', 'DIS.csv', 'COF.csv', 'SQ.csv', 'UA.csv', 'CRM.csv']

# %% [markdown]
# <h4>3. Create a database called 'sql_final_project' - 5 points</h4>

# %%
import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

mycursor.execute('Create Database If Not Exists sql_final_project;')

mydb.commit()
mydb.close()

# %% [markdown]
# <h4>4. Print the name of all existing databases - 5 points</h4>

# %%
import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

mycursor.execute('Show Databases;')
for x in mycursor:
  print(x)

mydb.close()
# Out:
# ('BookstoScrape',)
# ('Chinook',)
# ('CountryData',)
# ('information_schema',)
# ('Mock_Data',)
# ('MovieRank',)
# ('mysql',)
# ('PartData',)
# ('performance_schema',)
# ('pets',)
# ('RandomCo',)
# ('sql_final_project',)
# ('sys',)
# ('zipcodes',)

# %% [markdown]
# <h4>5. Create the tables listed below using the proper data types: - 10 points</h4>
# - 'security_master' with the following fields: sec_symbol, trade_date, closing_price, volume (discard the rest)<br>
#   (THIS IS THE YAHOO FINANCE DATA)<br>
# - 'cust_accounts' with the following fields:<br>
#   acct_num, trade_type, gender, last_name, first_name, salary, city, state  <br>
# - 'cust_transactions' with the following fields: <br>
#   trade_date, sec_symbol, acct_num, trade_type, trade_lot, transaction_id<br>
# - 'corp_accounts' with the following fields:<br>
#   acct_num, acct_type, acct_name, trading_limit (drop the address and zip info)   <br>
# - 'corp_transactions' with the following fields: <br>
#   trade_date, sec_symbol, acct_num, trade_type, trade_lot, transaction_id<br>

# %%
import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

mycursor.execute('Use sql_final_project;')

# 'security_master' with the following fields: sec_symbol, trade_date, closing_price, volume (discard the rest)

mycursor.execute('Drop Table If Exists security_master;')
mycursor.execute('''Create Table If Not Exists security_master
(
sec_symbol      varchar(10)  Not Null, 
trade_date      Date         Not Null, 
closing_price   Float        Not Null, 
volume          int          Not Null);
''')

# mycursor.execute('Drop Table if Exists cust_accounts;')
# mycursor.execute('Drop Table if Exists cust_transactions;')

# # - 'cust_transactions' with the following fields: trade_date, sec_symbol, acct_num, trade_type, trade_lot, transaction_id
mycursor.execute('''Create Table If Not Exists cust_transactions
(
acct_num        varchar(100)    Not Null,
trade_date      Date            Not Null,
sec_symbol      varchar(25)     Not Null,
trade_type      varchar(10)     Not Null,
trade_lot       int(10)         Not Null,
transaction_id  int(20)         Not Null,
index(acct_num));
''')



# 'cust_accounts' with the following fields: acct_num, trade_type, gender, last_name, first_name, salary, city, state
mycursor.execute('''Create Table If Not Exists cust_accounts
(
acct_num        varchar(100)  Not Null,  
gender          varchar(1)  Not Null, 
last_name       varchar(100)Not Null,
first_name      varchar(100)    Not Null,
salary          int             Not Null,
city            varchar(50)     Not Null,
state           varchar(2)      Not Null,
Constraint fk_cust_acct_num
Foreign Key (acct_num)
  References cust_transactions(acct_num)
	On Update Cascade
    On Delete Cascade);
''')



# # # - 'corp_accounts' with the following fields: acct_num, acct_type, acct_name, trading_limit (drop the address and zip info)
mycursor.execute('''Create Table If Not Exists corp_accounts
(
acct_num        varchar(100)    Not Null    Primary Key,
acct_type       varchar(10)     Not Null,
acct_name       varchar(150)    Not Null,
trading_limit   Int(20)         Not Null,
city            varchar(100)    Not Null,
state           varchar(2)      Not Null);
''')

# # # - 'corp_transactions' with the following fields: trade_date, sec_symbol, acct_num, trade_type, trade_lot, transaction_id
mycursor.execute('''Create Table if Not Exists corp_transactions
(
acct_num    varchar(100)    Not Null,
trade_date  Date            Not Null, 
sec_symbol      varchar(10)     Not Null,
trade_type      varchar(10)     Not Null,
trade_lot       int(10)         Not Null,
transaction_id  int(20)         Not Null,
Constraint fk_corp_acct_num
Foreign Key (acct_num)
  References corp_accounts(acct_num)
    On update Cascade
    On delete Cascade);
''')


mydb.commit()
mydb.close()

# %% [markdown]
# <h4>6. Populate the security_master table - 10 points</h4>
#
# When testing this out, tack on a limit 25 or so , doing a select * on the table with no limit is very memory intensive!

# %%
# 'security_master' with the following fields: sec_symbol, trade_date, closing_price, volume (discard the rest)
import csv
import os

os.chdir(r'/Users/yani/Desktop/PY-112-MySQL/Final Project')

# files = os.listdir('.')

# py_files = [py_file for py_file in os.listdir('.') if py_file.endswith(".csv")]
# # print(py_files)

securities_files = [x for x in py_files if len(x) < 9]
# print(securities_files)

security_data = []
def extract_security_data(li = []):
    for x in li:
        sec_symbol = (x.split('.'))[0]
        with open(x, newline='') as csv_file:
            data = csv.DictReader(csv_file)
            for row in data:
                security_data.append((sec_symbol, row['Date'], row['Close'], row['Volume']))
    

extract_security_data(securities_files)
# print(security_data[:5])

''' Pupulate Table security_master'''

import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

mycursor.execute('Use sql_final_project;')

mycursor.executemany('''Insert Into security_master (sec_symbol, trade_date, closing_price, volume) Values (%s, %s, %s, %s);''', security_data)


mydb.commit()
mycursor.execute('''Select * From security_master Limit 25;''')

# for x in mycursor:
#   print(x)


mydb.close()

# %% [markdown]
# <h4>7. Calculate the highest closing price and lowest closing price for every security after 3/17/2020</h4>
# - 5 points

# %%
import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

mycursor.execute('Use sql_final_project;')
# Highest Closing Price
mycursor.execute('''Select * From security_master
Where trade_date > "2020-03-17"
Order By closing_price Desc
Limit 1;''')

highest_closing_price = mycursor.fetchone()
print(highest_closing_price)

# Lowest Closing Price
mycursor.execute('''Select * From security_master
Where trade_date > "2020-03-17"
Order By closing_price 
Limit 1;''')

lowest_closing_price = mycursor.fetchone()
print(lowest_closing_price)

mydb.close()
# Out:
# ('CMG', datetime.date(2021, 7, 14), 1619.98, 228000)
# ('UA', datetime.date(2020, 4, 2), 6.89, 5159910)

# %% [markdown]
# <h4>8. Import and clean the following files</h4>
# 1. corp_accounts.csv<br>
# 2. corp_transactions<br>
# 3. cust_accounts<br>
# 4. cust_transactions<br>
# 5 points
#
# i.e.
#
# ```
# CO-37971|CORP|rahway racing|5363 Broadway Avenue|greenwich| CT   | 30437-0811|$93900000
# ```
# - get rid of trailing white spaces in corp_accounts.csv.
#
# ```
# CU-99956733,RMS,M,CHAVEZ, alexander,$150755,saratoga%springs,NY,
# ```
# - get rid of % and trailing comma in the names of places in cust_accounts.csv

# %%
'''Cleaning Data and Importing into cust_transactions'''
import csv
import os
import string

os.chdir(r'/Users/yani/Desktop/PY-112-MySQL/Final Project')

# 'cust_transactions': acct_num, trade_date, sec_symbol, trade_type, trade_lot, transaction_id
with open('cust_transactions.csv', newline = '') as cust_transactions:
    data2 = csv.DictReader(cust_transactions)
    cust_transactions_li = []
    symbols = string.printable[(string.printable.index('!')):].replace('-','')
    for row in data2:
        # Removes symbols (except '-') found in any of the dict values:
        for x,y in row.items():
            for i in y:
                if i in symbols:
                    # print(row)
                    row[x] = str(y).replace(i, ' ')
        cust_transactions_li.append((row['acct_num'].strip().upper(), row['trade_date'].strip(), row['sec_symbol'].strip().upper(), row['trade_type'].upper().strip(), row['trade_lot'].strip(), row['transaction_id'].strip()))

# print(cust_transactions_li[:2])


import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

# mycursor.executemany('''Insert Into cust_transactions (acct_num, trade_date, sec_symbol, trade_type, trade_lot, transaction_id) Values (%s, %s, %s, %s, %s, %s);''', cust_transactions_li)


mycursor.execute('''Select * From cust_transactions Limit 25;''')
# mydb.commit()
for x in mycursor:
    print(x)


mydb.close()
# Out:
# ('CU-45183405', datetime.date(2016, 7, 15), 'SQ', 'BUY', 4400, 7629245)
# ('CU-45183405', datetime.date(2017, 8, 29), 'SQ', 'SELL', 4400, 7629245)
# ('CU-45183405', datetime.date(2016, 6, 8), 'SQ', 'BUY', 9800, 4853151)
# ('CU-45183405', datetime.date(2017, 6, 26), 'SQ', 'SELL', 9800, 4853151)
# ('CU-45183405', datetime.date(2016, 4, 21), 'INTC', 'BUY', 2000, 5589988)
# ('CU-45183405', datetime.date(2017, 2, 14), 'INTC', 'SELL', 2000, 5589988)
# ('CU-45183405', datetime.date(2016, 6, 13), 'AMD', 'BUY', 5600, 5817103)
# ('CU-45183405', datetime.date(2017, 1, 3), 'AMD', 'SELL', 5600, 5817103)
# ('CU-45183405', datetime.date(2016, 7, 7), 'INTC', 'BUY', 9500, 6774282)
# ('CU-45183405', datetime.date(2016, 12, 6), 'INTC', 'SELL', 9500, 6774282)
# ('CU-45183405', datetime.date(2016, 7, 21), 'DIS', 'BUY', 4400, 9200893)
# ('CU-45183405', datetime.date(2017, 8, 10), 'DIS', 'SELL', 4400, 9200893)
# ('CU-45183405', datetime.date(2016, 5, 25), 'SQ', 'BUY', 1700, 5167092)
# ('CU-45183405', datetime.date(2017, 7, 21), 'SQ', 'SELL', 1700, 5167092)
# ('CU-45183405', datetime.date(2016, 4, 21), 'NKE', 'BUY', 9800, 1507096)
# ('CU-45183405', datetime.date(2017, 1, 3), 'NKE', 'SELL', 9800, 1507096)
# ('CU-45183405', datetime.date(2016, 7, 6), 'SQ', 'BUY', 4700, 4096787)
# ('CU-45183405', datetime.date(2017, 6, 30), 'SQ', 'SELL', 4700, 4096787)
# ('CU-45183405', datetime.date(2016, 8, 5), 'CMG', 'BUY', 7700, 5413113)
# ('CU-45183405', datetime.date(2017, 8, 18), 'CMG', 'SELL', 7700, 5413113)
# ('CU-04251390', datetime.date(2016, 7, 28), 'COF', 'BUY', 3900, 7288335)
# ('CU-04251390', datetime.date(2017, 3, 14), 'COF', 'SELL', 3900, 7288335)
# ('CU-04251390', datetime.date(2016, 5, 19), 'CRM', 'BUY', 1300, 4509206)
# ('CU-04251390', datetime.date(2017, 6, 16), 'CRM', 'SELL', 1300, 4509206)
# ('CU-04251390', datetime.date(2016, 6, 13), 'CMG', 'BUY', 2700, 6057929)

# %%
'''Cleaning Data and importing into cust_accounts'''
import csv
import os
import string
import pprint

os.chdir(r'/Users/yani/Desktop/PY-112-MySQL/Final Project')

import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()
# 'cust_accounts': acct_num, trade_type (will come from the cust_transactions table), gender, last_name, first_name, salary, city, state

with open('cust_accounts.csv', newline = '') as cust_accounts:
    data1 = csv.DictReader(cust_accounts)
    
    # Get string of symbols from ascii characters:
    symbols = string.printable[(string.printable.index('!')):].replace('-','')
    for row in data1:
        row.pop('') #Removes the dict key, value pair for the random keyname = None.  
        # Removes symbols (except '-') found in any of the dict values:
        for x,y in row.items():
            for i in y:
                if i in symbols:
                    # print(row)
                    row[x] = str(y).replace(i, ' ')
        row['acct_num'] = row['acct_num'].strip().upper()
        # print(row['acct_num'])
        row['gender'] = str(row['gender'].strip())
        row['last_name'] = row['last_name'].strip().capitalize()
        row['first_name'] = row['first_name'].strip().capitalize()
        row['salary'] = row['salary'].replace("$", "").strip()
        row['city'] = row['city'].strip().title()
        row['state'] = row['state'].strip().upper()

        # Could not insert data using executemany.
        cust_accounts_tuple = (row['acct_num'], row['gender'], row['last_name'], row['first_name'], row['salary'], row['city'], row['state'])
        query = f'''Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values {cust_accounts_tuple}'''
        # print(query)

        mycursor.execute(query)
        
mydb.commit()
mydb.close()
# Out:
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-45183405', 'M', 'Smith', 'James', '257474', 'Cohoes', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-04251390', 'M', 'Smith', 'John', '278990', 'White Plains', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-55235980', 'M', 'Smith', 'Robert', '341644', 'Middletown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-78499934', 'M', 'Smith', 'Michael', '108903', 'Olean', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44185123', 'M', 'Smith', 'William', '216565', 'Rye', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-23748349', 'M', 'Smith', 'David', '134271', 'Amsterdam', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-17008184', 'M', 'Smith', 'Richard', '280657', 'Long Beach', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-79869361', 'M', 'Smith', 'Joseph', '266942', 'Niagara Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-11563180', 'M', 'Smith', 'Thomas', '238296', 'White Plains', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-40468657', 'M', 'Smith', 'Charles', '234395', 'Sherrill', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92157980', 'M', 'Smith', 'Christopher', '156180', 'Sherrill', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26594150', 'M', 'Smith', 'Daniel', '116543', 'Elmira', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-62815828', 'M', 'Smith', 'Matthew', '343866', 'Rye', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-17216350', 'M', 'Smith', 'Anthony', '296086', 'Fulton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37785635', 'M', 'Smith', 'Donald', '303961', 'Middletown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-07325267', 'M', 'Smith', 'Mark', '218151', 'Syracuse', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-93275722', 'M', 'Smith', 'Paul', '289153', 'Binghamton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37084832', 'M', 'Smith', 'Steven', '122497', 'Plattsburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-06283403', 'M', 'Smith', 'Andrew', '251888', 'Oneida', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-33002221', 'M', 'Smith', 'Kenneth', '93031', 'Syracuse', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-95525351', 'M', 'Smith', 'Joshua', '150929', 'Corning', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-06852250', 'M', 'Smith', 'Kevin', '168146', 'Buffalo', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44826544', 'M', 'Smith', 'Brian', '180341', 'Peekskill', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-64240662', 'M', 'Smith', 'George', '200948', 'Canandaigua', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-77922426', 'M', 'Smith', 'Edward', '282851', 'Binghamton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-65325484', 'M', 'Smith', 'Ronald', '117940', 'Hudson', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-78676250', 'M', 'Smith', 'Timothy', '302503', 'Elmira', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57454440', 'M', 'Smith', 'Jason', '328478', 'Middletown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-55664785', 'M', 'Smith', 'Jeffrey', '103336', 'Oneonta', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-13492581', 'M', 'Smith', 'Ryan', '230063', 'Ogdensburg', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-06084221', 'M', 'Smith', 'Jacob', '118329', 'Dunkirk', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57175956', 'M', 'Smith', 'Gary', '53122', 'Rochester', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-36231403', 'M', 'Smith', 'Nicholas', '190651', 'Lackawanna', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-81204126', 'M', 'Smith', 'Eric', '215923', 'Lackawanna', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-86693052', 'M', 'Smith', 'Jonathan', '206708', 'Watervliet', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-68723001', 'M', 'Smith', 'Stephen', '129927', 'Mount Vernon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-18572674', 'M', 'Smith', 'Larry', '271716', 'Plattsburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-74321794', 'M', 'Smith', 'Justin', '154538', 'Rensselaer', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-36440616', 'M', 'Smith', 'Scott', '165454', 'Batavia', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-58886676', 'M', 'Smith', 'Brandon', '108688', 'Hudson', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-38902600', 'M', 'Smith', 'Benjamin', '73880', 'Rome', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-08650375', 'M', 'Smith', 'Samuel', '184057', 'Cohoes', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80347565', 'M', 'Smith', 'Frank', '330204', 'Corning', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-34716314', 'M', 'Smith', 'Gregory', '190685', 'Middletown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44542009', 'M', 'Smith', 'Raymond', '257092', 'Rochester', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-45316123', 'M', 'Smith', 'Alexander', '175111', 'Beacon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-32785008', 'M', 'Smith', 'Patrick', '144049', 'Mount Vernon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-29292141', 'M', 'Smith', 'Jack', '336384', 'Troy', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-06527721', 'M', 'Smith', 'Dennis', '214226', 'Peekskill', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-40777575', 'M', 'Smith', 'Jerry', '129408', 'Buffalo', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-32332356', 'M', 'Smith', 'Tyler', '253816', 'Salamanca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-04404342', 'M', 'Smith', 'Aaron', '269912', 'Oneida', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-41623086', 'M', 'Smith', 'Jose', '66422', 'Niagara Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-06436134', 'M', 'Smith', 'Henry', '122060', 'Binghamton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-08634251', 'M', 'Smith', 'Adam', '74911', 'Glen Cove', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-33497108', 'M', 'Smith', 'Douglas', '102596', 'Corning', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-00708019', 'M', 'Smith', 'Nathan', '109402', 'Johnstown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-39478099', 'M', 'Smith', 'Peter', '190375', 'North Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-62795429', 'M', 'Smith', 'Zachary', '250343', 'Corning', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-12727579', 'M', 'Smith', 'Kyle', '164137', 'Johnstown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-46411999', 'M', 'Smith', 'Walter', '341315', 'Little Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-59181462', 'M', 'Smith', 'Harold', '237967', 'Rome', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-89351358', 'M', 'Smith', 'Jeremy', '298385', 'Watervliet', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-84261830', 'M', 'Smith', 'Ethan', '210875', 'Batavia', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-69552028', 'M', 'Smith', 'Carl', '176209', 'Hornell', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-66158070', 'M', 'Smith', 'Keith', '56421', 'Newburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-15500695', 'M', 'Smith', 'Roger', '349084', 'Cortland', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92351886', 'M', 'Smith', 'Gerald', '170144', 'Mount Vernon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-78518115', 'M', 'Smith', 'Christian', '243137', 'Dunkirk', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-97911563', 'M', 'Smith', 'Terry', '71512', 'Port Jervis', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26636784', 'M', 'Smith', 'Sean', '148138', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-38732904', 'M', 'Smith', 'Arthur', '254511', 'Middletown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-56262733', 'M', 'Smith', 'Austin', '284294', 'Lockport', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-60973635', 'M', 'Smith', 'Noah', '166279', 'Sherrill', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-16578844', 'M', 'Smith', 'Lawrence', '84830', 'Plattsburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-03083033', 'M', 'Smith', 'Jesse', '345362', 'Rye', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-71698548', 'M', 'Smith', 'Joe', '300025', 'Glen Cove', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-64711477', 'M', 'Smith', 'Bryan', '63554', 'Rye', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-43234740', 'M', 'Smith', 'Billy', '153501', 'Mechanicville', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-63694846', 'M', 'Smith', 'Jordan', '226314', 'Schenectady', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57546871', 'M', 'Smith', 'Albert', '193369', 'Ogdensburg', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-55405720', 'M', 'Smith', 'Dylan', '173475', 'Beacon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57279720', 'M', 'Smith', 'Bruce', '308944', 'Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-20723057', 'M', 'Smith', 'Willie', '228816', 'Glens Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-83729846', 'M', 'Smith', 'Gabriel', '345278', 'Niagara Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-25516448', 'M', 'Smith', 'Alan', '285189', 'Fulton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-05679165', 'M', 'Smith', 'Juan', '260387', 'Geneva', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-90304798', 'M', 'Smith', 'Logan', '227222', 'Long Beach', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-69226186', 'M', 'Smith', 'Wayne', '212181', 'Rye', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-07358832', 'M', 'Smith', 'Ralph', '93529', 'Amsterdam', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-45588179', 'M', 'Smith', 'Roy', '287999', 'Saratoga Springs', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-84452117', 'M', 'Smith', 'Eugene', '78398', 'Glen Cove', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-02627721', 'M', 'Smith', 'Randy', '262834', 'Oneida', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-82736766', 'M', 'Smith', 'Vincent', '158315', 'Schenectady', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-93101088', 'M', 'Smith', 'Russell', '241664', 'Saratoga Springs', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-13610486', 'M', 'Smith', 'Louis', '82500', 'Hornell', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-87466495', 'M', 'Smith', 'Philip', '57609', 'Mechanicville', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-32479603', 'M', 'Smith', 'Bobby', '50406', 'Jamestown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-07230978', 'M', 'Smith', 'Johnny', '76254', 'Rome', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-53083262', 'M', 'Smith', 'Bradley', '209046', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-05265035', 'F', 'Smith', 'Mary', '113876', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-64948211', 'F', 'Smith', 'Patricia', '82761', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26398520', 'F', 'Smith', 'Jennifer', '218308', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-55184621', 'F', 'Smith', 'Linda', '172488', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-98966439', 'F', 'Smith', 'Elizabeth', '244562', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-21506507', 'F', 'Smith', 'Barbara', '137553', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-86252271', 'F', 'Smith', 'Susan', '269712', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-41338146', 'F', 'Smith', 'Jessica', '136494', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-08263847', 'F', 'Smith', 'Sarah', '82964', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-34916849', 'F', 'Smith', 'Karen', '202294', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-20375310', 'F', 'Smith', 'Nancy', '110097', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-53646949', 'F', 'Smith', 'Lisa', '275931', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-46752035', 'F', 'Smith', 'Margaret', '34281', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-18016233', 'F', 'Smith', 'Betty', '232151', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-63523063', 'F', 'Smith', 'Sandra', '109225', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-07582501', 'F', 'Smith', 'Ashley', '103308', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-86067717', 'F', 'Smith', 'Dorothy', '87196', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-56858435', 'F', 'Smith', 'Kimberly', '41341', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-87762624', 'F', 'Smith', 'Emily', '86609', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-75880621', 'F', 'Smith', 'Donna', '53455', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92724993', 'F', 'Smith', 'Michelle', '124910', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-95138288', 'F', 'Smith', 'Carol', '224282', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-51033650', 'F', 'Smith', 'Amanda', '247699', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80954195', 'F', 'Smith', 'Melissa', '169917', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-19547669', 'F', 'Smith', 'Deborah', '43821', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-48212852', 'F', 'Smith', 'Stephanie', '99727', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-35787865', 'F', 'Smith', 'Rebecca', '205197', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-78430159', 'F', 'Smith', 'Laura', '186510', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-71455392', 'F', 'Smith', 'Sharon', '241043', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-11840527', 'F', 'Smith', 'Cynthia', '247875', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-90666238', 'F', 'Smith', 'Kathleen', '201432', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-33577084', 'F', 'Smith', 'Amy', '102262', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-82658056', 'F', 'Smith', 'Shirley', '189258', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44757895', 'F', 'Smith', 'Angela', '110206', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57409196', 'F', 'Smith', 'Helen', '160494', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-62093726', 'F', 'Smith', 'Anna', '64980', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-76694878', 'F', 'Smith', 'Brenda', '49541', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-70683588', 'F', 'Smith', 'Pamela', '168183', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-51476956', 'F', 'Smith', 'Nicole', '56564', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-86361680', 'F', 'Smith', 'Samantha', '122480', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-89607415', 'F', 'Smith', 'Katherine', '227234', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-88633301', 'F', 'Smith', 'Emma', '170503', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-02206520', 'F', 'Smith', 'Ruth', '150269', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92023597', 'F', 'Smith', 'Christine', '158889', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-99720177', 'F', 'Smith', 'Catherine', '216960', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44544182', 'F', 'Smith', 'Debra', '47842', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-72754540', 'F', 'Smith', 'Rachel', '87637', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-13779001', 'F', 'Smith', 'Carolyn', '106578', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-79732490', 'F', 'Smith', 'Janet', '141946', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-07446929', 'F', 'Smith', 'Virginia', '168308', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-19820444', 'F', 'Smith', 'Maria', '175284', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-07560831', 'F', 'Smith', 'Heather', '249506', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-16205304', 'F', 'Smith', 'Diane', '70892', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26443398', 'F', 'Smith', 'Julie', '255043', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-70370711', 'F', 'Smith', 'Joyce', '166973', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-88426972', 'F', 'Smith', 'Victoria', '99913', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-34608193', 'F', 'Smith', 'Kelly', '114401', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-59358240', 'F', 'Smith', 'Christina', '215514', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-10000652', 'F', 'Smith', 'Lauren', '195297', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-40075775', 'F', 'Smith', 'Joan', '159170', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-16453082', 'F', 'Smith', 'Evelyn', '201806', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-05469269', 'F', 'Smith', 'Olivia', '57599', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-49724081', 'F', 'Smith', 'Judith', '228041', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-97028099', 'F', 'Smith', 'Megan', '108459', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-58413529', 'F', 'Smith', 'Cheryl', '220137', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-96551244', 'F', 'Smith', 'Martha', '74736', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-67501489', 'F', 'Smith', 'Andrea', '89617', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26986165', 'F', 'Smith', 'Frances', '190091', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-42230253', 'F', 'Smith', 'Hannah', '102832', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-91925492', 'F', 'Smith', 'Jacqueline', '122578', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-54020187', 'F', 'Smith', 'Ann', '136989', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-72181672', 'F', 'Smith', 'Gloria', '172846', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-16279350', 'F', 'Smith', 'Jean', '210085', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-86369163', 'F', 'Smith', 'Kathryn', '107247', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-49090327', 'F', 'Smith', 'Alice', '101518', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-95550738', 'F', 'Smith', 'Teresa', '187362', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-03394127', 'F', 'Smith', 'Sara', '119905', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80532017', 'F', 'Smith', 'Janice', '87277', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-16700500', 'F', 'Smith', 'Doris', '80779', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-77570617', 'F', 'Smith', 'Madison', '71864', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-78220377', 'F', 'Smith', 'Julia', '212645', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-72260328', 'F', 'Smith', 'Grace', '81731', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-49900281', 'F', 'Smith', 'Judy', '30936', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-51897039', 'F', 'Smith', 'Abigail', '95596', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44162064', 'F', 'Smith', 'Marie', '249597', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-01564799', 'F', 'Smith', 'Denise', '35777', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37837232', 'F', 'Smith', 'Beverly', '282229', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-67532801', 'F', 'Smith', 'Amber', '50012', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-91580446', 'F', 'Smith', 'Theresa', '105248', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-45639231', 'F', 'Smith', 'Marilyn', '102424', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-62241739', 'F', 'Smith', 'Danielle', '238975', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-60271056', 'F', 'Smith', 'Diana', '102546', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-49618286', 'F', 'Smith', 'Brittany', '272461', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-65200782', 'F', 'Smith', 'Natalie', '193966', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-32784007', 'F', 'Smith', 'Sophia', '209817', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-85149581', 'F', 'Smith', 'Rose', '194812', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-01397816', 'F', 'Smith', 'Isabella', '96266', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-81751038', 'F', 'Smith', 'Alexis', '96546', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-97280682', 'F', 'Smith', 'Kayla', '38056', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-77503789', 'F', 'Smith', 'Charlotte', '276227', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-24578511', 'M', 'Johnson', 'James', '345731', 'Lackawanna', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-52087796', 'M', 'Johnson', 'John', '322519', 'Plattsburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-02616274', 'M', 'Johnson', 'Robert', '205831', 'Oneonta', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-99073064', 'M', 'Johnson', 'Michael', '240821', 'Troy', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-38903273', 'M', 'Johnson', 'William', '158114', 'Newburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-17989754', 'M', 'Johnson', 'David', '64443', 'Rochester', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80816055', 'M', 'Johnson', 'Richard', '331502', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-84776302', 'M', 'Johnson', 'Joseph', '324174', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-52362991', 'M', 'Johnson', 'Thomas', '288920', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-68456883', 'M', 'Johnson', 'Charles', '327889', 'Long Beach', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92789150', 'M', 'Johnson', 'Christopher', '189170', 'Rensselaer', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-88502665', 'M', 'Johnson', 'Daniel', '74978', 'New York', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-17202937', 'M', 'Johnson', 'Matthew', '254762', 'Batavia', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-67999568', 'M', 'Johnson', 'Anthony', '191290', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-47390958', 'M', 'Johnson', 'Donald', '201371', 'Ogdensburg', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-39507133', 'M', 'Johnson', 'Mark', '248711', 'New Rochelle', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-70480896', 'M', 'Johnson', 'Paul', '89550', 'Albany', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-90172455', 'M', 'Johnson', 'Steven', '59940', 'Oneonta', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-27966303', 'M', 'Johnson', 'Andrew', '280830', 'New Rochelle', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-62169425', 'M', 'Johnson', 'Kenneth', '329197', 'Ogdensburg', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-70454924', 'M', 'Johnson', 'Joshua', '60368', 'Rome', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-75229250', 'M', 'Johnson', 'Kevin', '342795', 'Kingston', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57721041', 'M', 'Johnson', 'Brian', '98012', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-62443359', 'M', 'Johnson', 'George', '334573', 'Rome', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-88821651', 'M', 'Johnson', 'Edward', '142709', 'North Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-14544550', 'M', 'Johnson', 'Ronald', '192254', 'Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37150154', 'M', 'Johnson', 'Timothy', '226587', 'Newburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-82801696', 'M', 'Johnson', 'Jason', '316995', 'Fulton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-99984836', 'M', 'Johnson', 'Jeffrey', '157638', 'Rensselaer', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-94120738', 'M', 'Johnson', 'Ryan', '56429', 'North Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-39956758', 'M', 'Johnson', 'Jacob', '258045', 'North Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-87703637', 'M', 'Johnson', 'Gary', '335145', 'Saratoga Springs', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-21430159', 'M', 'Johnson', 'Nicholas', '285704', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-74418304', 'M', 'Johnson', 'Eric', '217033', 'Beacon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-46634184', 'M', 'Johnson', 'Jonathan', '147846', 'Dunkirk', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-77034556', 'M', 'Johnson', 'Stephen', '205828', 'Salamanca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-11090779', 'M', 'Johnson', 'Larry', '322810', 'Lockport', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-71467291', 'M', 'Johnson', 'Justin', '280053', 'Olean', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-41751651', 'M', 'Johnson', 'Scott', '141159', 'Syracuse', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-66980728', 'M', 'Johnson', 'Brandon', '324362', 'Fulton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-08580321', 'M', 'Johnson', 'Benjamin', '212168', 'Norwich', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57677137', 'M', 'Johnson', 'Samuel', '251697', 'New Rochelle', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-83816294', 'M', 'Johnson', 'Frank', '120878', 'Glen Cove', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-93841679', 'M', 'Johnson', 'Gregory', '194966', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-45375336', 'M', 'Johnson', 'Raymond', '192902', 'Glens Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-78051136', 'M', 'Johnson', 'Alexander', '313892', 'Olean', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-83022104', 'M', 'Johnson', 'Patrick', '199199', 'Albany', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-51207025', 'M', 'Johnson', 'Jack', '281751', 'Schenectady', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80776933', 'M', 'Johnson', 'Dennis', '307284', 'Lackawanna', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26534328', 'M', 'Johnson', 'Jerry', '346397', '', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37068729', 'M', 'Johnson', 'Tyler', '338584', 'White Plains', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-47938796', 'M', 'Johnson', 'Aaron', '162501', 'Salamanca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-03690134', 'M', 'Johnson', 'Jose', '51853', 'Newburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-06351206', 'M', 'Johnson', 'Henry', '286665', 'Niagara Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-29265249', 'M', 'Johnson', 'Adam', '69431', 'Port Jervis', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-39432855', 'M', 'Johnson', 'Douglas', '288311', 'Oneida', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-20619384', 'M', 'Johnson', 'Nathan', '128901', 'Geneva', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-64810627', 'M', 'Johnson', 'Peter', '109035', 'Schenectady', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-07307763', 'M', 'Johnson', 'Zachary', '190877', 'Hornell', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-94436145', 'M', 'Johnson', 'Kyle', '74645', 'Oneonta', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80185191', 'M', 'Johnson', 'Walter', '221977', 'Newburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-22578408', 'M', 'Johnson', 'Harold', '168867', 'Beacon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-63758348', 'M', 'Johnson', 'Jeremy', '324336', 'Albany', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-81705168', 'M', 'Johnson', 'Ethan', '303701', 'Rome', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-36609689', 'M', 'Johnson', 'Carl', '234054', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-06512834', 'M', 'Johnson', 'Keith', '318915', 'Watertown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-34078201', 'M', 'Johnson', 'Roger', '321013', 'Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-52677232', 'M', 'Johnson', 'Gerald', '335990', 'Cortland', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44444372', 'M', 'Johnson', 'Christian', '86871', 'Fulton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-88246007', 'M', 'Johnson', 'Terry', '181088', 'Mechanicville', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-13114073', 'M', 'Johnson', 'Sean', '91083', 'Oswego', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-77997786', 'M', 'Johnson', 'Arthur', '308348', 'Oneida', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-46668693', 'M', 'Johnson', 'Austin', '136773', 'Canandaigua', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-35940172', 'M', 'Johnson', 'Noah', '67206', 'Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-22752939', 'M', 'Johnson', 'Lawrence', '101425', 'Gloversville', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-54429579', 'M', 'Johnson', 'Jesse', '60262', 'Glens Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-57955544', 'M', 'Johnson', 'Joe', '261324', 'Rensselaer', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-98970077', 'M', 'Johnson', 'Bryan', '301197', 'Glens Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-99045052', 'M', 'Johnson', 'Billy', '234202', 'New Rochelle', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-02495229', 'M', 'Johnson', 'Jordan', '152827', 'Plattsburgh', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-95965815', 'M', 'Johnson', 'Albert', '110894', 'Canandaigua', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-27512647', 'M', 'Johnson', 'Dylan', '283045', 'New Rochelle', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-18799227', 'M', 'Johnson', 'Bruce', '293045', 'Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92507433', 'M', 'Johnson', 'Willie', '231939', 'Little Falls', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-65061710', 'M', 'Johnson', 'Gabriel', '225839', 'New Rochelle', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-94170817', 'M', 'Johnson', 'Alan', '275484', 'Cortland', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-68453787', 'M', 'Johnson', 'Juan', '263812', 'Canandaigua', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-89018306', 'M', 'Johnson', 'Logan', '135183', 'Norwich', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26164125', 'M', 'Johnson', 'Wayne', '255715', 'Peekskill', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-89858268', 'M', 'Johnson', 'Ralph', '192567', 'Yonkers', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-27230665', 'M', 'Johnson', 'Roy', '148485', 'Beacon', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-64245681', 'M', 'Johnson', 'Eugene', '72024', 'Binghamton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-85801307', 'M', 'Johnson', 'Randy', '64448', 'Kingston', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-27469978', 'M', 'Johnson', 'Vincent', '202281', 'Ogdensburg', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-18365371', 'M', 'Johnson', 'Russell', '291002', 'Oneida', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-12544753', 'M', 'Johnson', 'Louis', '65624', 'Hudson', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-86711846', 'M', 'Johnson', 'Philip', '106016', 'Fulton', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-24243628', 'M', 'Johnson', 'Bobby', '259372', 'Poughkeepsie', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-26552884', 'M', 'Johnson', 'Johnny', '79981', 'Tonawanda', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-42870540', 'M', 'Johnson', 'Bradley', '127372', 'Middletown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-53202496', 'F', 'Johnson', 'Mary', '140218', 'Middletown', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-74623477', 'F', 'Johnson', 'Patricia', '253298', 'Middletown', 'NY')
# ...
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-83179736', 'M', 'Jimenez', 'Bradley', '232203', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-97317555', 'F', 'Jimenez', 'Mary', '240967', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-29443048', 'F', 'Jimenez', 'Patricia', '226888', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-04866501', 'F', 'Jimenez', 'Jennifer', '246606', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92847046', 'F', 'Jimenez', 'Linda', '37657', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-46035529', 'F', 'Jimenez', 'Elizabeth', '282593', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-21762844', 'F', 'Jimenez', 'Barbara', '251210', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-14116674', 'F', 'Jimenez', 'Susan', '180911', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-61630521', 'F', 'Jimenez', 'Jessica', '136844', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-11265363', 'F', 'Jimenez', 'Sarah', '38400', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-63660276', 'F', 'Jimenez', 'Karen', '167202', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-29969356', 'F', 'Jimenez', 'Nancy', '197073', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-16547391', 'F', 'Jimenez', 'Lisa', '240473', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-14448298', 'F', 'Jimenez', 'Margaret', '84057', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-72214692', 'F', 'Jimenez', 'Betty', '178109', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-56292963', 'F', 'Jimenez', 'Sandra', '219249', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-56523559', 'F', 'Jimenez', 'Ashley', '209599', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-51966726', 'F', 'Jimenez', 'Dorothy', '172306', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-43984002', 'F', 'Jimenez', 'Kimberly', '209493', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-31398825', 'F', 'Jimenez', 'Emily', '131346', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-90773642', 'F', 'Jimenez', 'Donna', '197022', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-77585546', 'F', 'Jimenez', 'Michelle', '143030', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-44844097', 'F', 'Jimenez', 'Carol', '188165', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-54530283', 'F', 'Jimenez', 'Amanda', '56604', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-70355115', 'F', 'Jimenez', 'Melissa', '228898', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92876345', 'F', 'Jimenez', 'Deborah', '146892', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-74512026', 'F', 'Jimenez', 'Stephanie', '122489', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-96798672', 'F', 'Jimenez', 'Rebecca', '110305', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-08680172', 'F', 'Jimenez', 'Laura', '64296', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-88078516', 'F', 'Jimenez', 'Sharon', '197528', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-33733047', 'F', 'Jimenez', 'Cynthia', '233881', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-96676076', 'F', 'Jimenez', 'Kathleen', '88284', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-14564609', 'F', 'Jimenez', 'Amy', '114890', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-67236472', 'F', 'Jimenez', 'Shirley', '186177', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-41177006', 'F', 'Jimenez', 'Angela', '175641', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-17069585', 'F', 'Jimenez', 'Helen', '254200', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-98233646', 'F', 'Jimenez', 'Anna', '287870', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-86345304', 'F', 'Jimenez', 'Brenda', '77260', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-92049619', 'F', 'Jimenez', 'Pamela', '131452', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-16535435', 'F', 'Jimenez', 'Nicole', '179862', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-15116882', 'F', 'Jimenez', 'Samantha', '129685', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-09181251', 'F', 'Jimenez', 'Katherine', '252984', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37058277', 'F', 'Jimenez', 'Emma', '219772', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80026240', 'F', 'Jimenez', 'Ruth', '280195', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-20931124', 'F', 'Jimenez', 'Christine', '76334', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-02996451', 'F', 'Jimenez', 'Catherine', '245105', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-52034487', 'F', 'Jimenez', 'Debra', '75603', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-35148439', 'F', 'Jimenez', 'Rachel', '185530', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-29284222', 'F', 'Jimenez', 'Carolyn', '51848', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-27882185', 'F', 'Jimenez', 'Janet', '118847', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-84222693', 'F', 'Jimenez', 'Virginia', '132312', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-79688250', 'F', 'Jimenez', 'Maria', '217545', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-74847728', 'F', 'Jimenez', 'Heather', '159880', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-42842798', 'F', 'Jimenez', 'Diane', '225773', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-18891257', 'F', 'Jimenez', 'Julie', '225488', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-93609940', 'F', 'Jimenez', 'Joyce', '126511', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-14103558', 'F', 'Jimenez', 'Victoria', '191695', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-90370460', 'F', 'Jimenez', 'Kelly', '215395', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-62953257', 'F', 'Jimenez', 'Christina', '185413', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-38362458', 'F', 'Jimenez', 'Lauren', '171215', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-97477627', 'F', 'Jimenez', 'Joan', '92642', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-76514166', 'F', 'Jimenez', 'Evelyn', '167171', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-64918202', 'F', 'Jimenez', 'Olivia', '148328', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-42010142', 'F', 'Jimenez', 'Judith', '175545', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-35307593', 'F', 'Jimenez', 'Megan', '218387', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-55087370', 'F', 'Jimenez', 'Cheryl', '163789', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-40767816', 'F', 'Jimenez', 'Martha', '274059', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-79412215', 'F', 'Jimenez', 'Andrea', '232096', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-65596511', 'F', 'Jimenez', 'Frances', '261348', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-11433732', 'F', 'Jimenez', 'Hannah', '37325', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-98991370', 'F', 'Jimenez', 'Jacqueline', '150550', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-90495962', 'F', 'Jimenez', 'Ann', '67091', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-33601289', 'F', 'Jimenez', 'Gloria', '62415', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-21204153', 'F', 'Jimenez', 'Jean', '272808', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-34618672', 'F', 'Jimenez', 'Kathryn', '74172', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-88974998', 'F', 'Jimenez', 'Alice', '193972', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-14313544', 'F', 'Jimenez', 'Teresa', '50610', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-21837991', 'F', 'Jimenez', 'Sara', '86980', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-76983284', 'F', 'Jimenez', 'Janice', '138708', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-95119091', 'F', 'Jimenez', 'Doris', '234316', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-96347805', 'F', 'Jimenez', 'Madison', '275249', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-13209200', 'F', 'Jimenez', 'Julia', '214371', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-89508897', 'F', 'Jimenez', 'Grace', '162012', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-70883655', 'F', 'Jimenez', 'Judy', '271950', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37803749', 'F', 'Jimenez', 'Abigail', '254870', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-90416666', 'F', 'Jimenez', 'Marie', '30994', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-54576775', 'F', 'Jimenez', 'Denise', '92011', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-15463950', 'F', 'Jimenez', 'Beverly', '257675', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-25171037', 'F', 'Jimenez', 'Amber', '255408', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-08751888', 'F', 'Jimenez', 'Theresa', '132919', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-95546387', 'F', 'Jimenez', 'Marilyn', '154391', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-04961730', 'F', 'Jimenez', 'Danielle', '36253', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-28166410', 'F', 'Jimenez', 'Diana', '92191', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-76088838', 'F', 'Jimenez', 'Brittany', '137904', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-67118359', 'F', 'Jimenez', 'Natalie', '95923', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-91787317', 'F', 'Jimenez', 'Sophia', '61847', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-23624833', 'F', 'Jimenez', 'Rose', '235211', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-37417834', 'F', 'Jimenez', 'Isabella', '127660', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-80118397', 'F', 'Jimenez', 'Alexis', '49138', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-56561019', 'F', 'Jimenez', 'Kayla', '73290', 'Ithaca', 'NY')
# Insert Into cust_accounts (acct_num,gender,last_name,first_name,salary,city,state) Values ('CU-41117246', 'F', 'Jimenez', 'Charlotte', '254972', 'Ithaca', 'NY')

# %%
'''Cleaning Data and importing into corp_accounts'''
import csv
import os
import string

os.chdir(r'/Users/yani/Desktop/PY-112-MySQL/Final Project')

import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

# - 'corp_accounts': acct_num, acct_type, acct_name, trading_limit, city, state. (drop the address and zip info)
with open('corp_accounts.csv', newline = '') as corp_accounts:
    data3 = csv.DictReader(corp_accounts, delimiter = '|')
    
    symbols = string.printable[(string.printable.index('!')):].replace('-','')
    for row in data3:
      # Removes symbols (except '-') found in any of the dict values:
      for x,y in row.items():
        row[x] = y.strip()
        for i in y:
          if i in symbols:
            row[x] = str(y).replace(i, ' ')
      row['acct_num'] = row['acct_num'].strip().upper()
      row['acct_type'] = row['acct_type'].upper().strip()
      row['acct_name'] = row['acct_name'].title().strip()
      row['trading_limit'] = row['trading_limit'].strip()
      row['city'] = row['city'].strip().capitalize()
      row['state'] = row['state'].strip().upper()

      corp_accounts_tuple = (row['acct_num'], row['acct_type'], row['acct_name'], row['trading_limit'], row['city'], row['state'])

      query = f'''Insert Into corp_accounts (acct_num, acct_type, acct_name, trading_limit, city, state) Values {corp_accounts_tuple}'''
      mycursor.execute(query)

mydb.commit()
mydb.close()

# %%
'''Cleaning Data and importing into corp_transactions'''
import csv
import os
import string

os.chdir(r'/Users/yani/Desktop/PY-112-MySQL/Final Project')

# - 'corp_transactions': acct_num, trade_date, sec_symbol, trade_type, trade_lot, transaction_id
with open('corp_transactions.csv', newline = '') as corp_transactions:
    data4 = csv.DictReader(corp_transactions)
    corp_transactions_li = []
    symbols = string.printable[(string.printable.index('!')):].replace('-','')
    for row in data4:
      # Removes symbols (except '-') found in any of the dict values:
      for x,y in row.items():
            for i in y:
                if i in symbols:
                    row[x] = str(y).replace(i, ' ')
      
      corp_transactions_li.append((row['acct_num'].strip().upper(), row['trade_date'].strip(), row['sec_symbol'].upper().strip(), row['trade_type'].upper().strip(), row['trade_lot'].strip(), row['transaction_id'].strip()))

# print(corp_transactions_li[:2])


import mysql.connector
from dotenv import dotenv_values

config = dotenv_values(".env")  

mydb = mysql.connector.connect(
  host=config['HOST'],
  user=config['USER'],
  password=config['PASSWORD'],
  database=config['DATABASE'])

mycursor = mydb.cursor()

mycursor.executemany('''Insert Into corp_transactions (acct_num, trade_date, sec_symbol, trade_type, trade_lot, transaction_id) Values (%s, %s, %s, %s, %s, %s);''', corp_transactions_li)


mydb.commit()
mydb.close()
# Out:
# [('CO-37971', '2016-07-18', 'COF', 'BUY', '60000', '01233572'), ('CO-37971', '2017-06-27', 'COF', 'SELL', '60000', '01233572')]

# %% [markdown]
# <h4>9. Load the data from the csv files into the tables you created and cleaned from step 8</h4>
# - 5 points

# %%
''' I loaded, cleaned and uploaded the data for each table in their own individual cells above. I did this due to not being able to add data using 'executemany' for some of the tables.'''

# %% [markdown]
# <h4>10. Calculate the Profit and Loss (PnL) for every trade in the customer accounts
# and corp accounts (2 SQL queries) by security by transaction</h4>
# 10 points

# %%
# Out:
# !"#$%&'()*+,./:;<=>?@[\]^_`{|}~

# %%
# your code here

# %% [markdown]
# <h4>11. Write a query to report by account number the total number of buys, sells, and shares traded per security
#     (For both customer and corporate accounts - 2 SQL queries)<br>
# </h4>
# 5 points + 5 Extra points for combining the 2 queries in one output

# %%
# your code here

# %% [markdown]
# <h4>12.  Calculate the 3 biggest losses per account per security</h4>
# 5 points

# %%
# your code here
Error Code: 1055. Expression #2 of SELECT list is not in GROUP BY clause and contains nonaggregated column 'sql_final_project.corp_transactions.sec_symbol' which is not functionally dependent on columns in GROUP BY clause; this is incompatible with sql_mode=only_full_group_by



Error Code: 1064. You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ', trade_type) As '# of Sells', (select count(trade_type)  from corp_transactions' at line 2

# %% [markdown]
# <h4>13. MSFT was on the restricted list for the corporate client Ether Trading from 1/1/2017 through 12/31/2017<br>
# Please list all trades for this client during this period and classify the restricted trades as 'ILLEGAL'<br>
# Part 2 is to fine them $10,000 for every trade.  How much in fines do they owe?</h4>
# 10 points

# %%
# your code here

# %% [markdown]
# <h4>14. The SEC wants you to send them a report of all trades done by the following customer accounts:<br>
# CU-94677950<br>
# CU-26735586<br>
# CU-04842147<br>
# CU-52277499<br>
# For the calendar year 2016 and 2017<br>
# The report should be written to disk and contain:<br>
# acct_num, last name, first name, security, trade date, lot size, current price on that day<br>
# The report should be in date order by security symbol<br>
# File name 'Suspicious_activity_YYYYMMDD.csv'<br>
# 10 points

# %%
# your code here

# %% [markdown]
# <h4>15. Label each trade on customer accounts as either 'STCG' for Short Term Capital Gains if <br>
# the trading length was under 365 days or 'LTCG' Long Term Capital Gains for each security held over 365 days<br>
# In customer order by trade date<br></h4>
# 5 points

# %%
# your code here

# %% [markdown]
# <H2>BONUS QUESTION - 15 points</H2>
# Create a table called trade_blotter<br>
# The columns will be trade date, the name of every security traded (Note: 10 columns for the security names)<br>
# populate the table

# %%
# your code here
